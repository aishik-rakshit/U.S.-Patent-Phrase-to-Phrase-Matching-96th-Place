# %%
! nvidia-smi
# Out:
# Mon Jun 20 06:52:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    51W / 350W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# ! gdown --id 1PUSJ56k93B42XW9oszcPDefM8HeJ2BOg
# ! pip -q uninstall -y kaggle
# ! pip -q install --upgrade pip
# ! pip -q install kaggle --upgrade
# ! mkdir ~/.kaggle
# ! cp kaggle.json ~/.kaggle/
# ! chmod 600 ~/.kaggle/kaggle.json
# ! kaggle competitions download us-patent-phrase-to-phrase-matching
# ! kaggle datasets download yasufuminakama/cpc-data
# ! kaggle datasets download fankaixie/pppm-abstract

# %%
# ! unzip -q /content/us-patent-phrase-to-phrase-matching.zip -d data
# ! rm /content/us-patent-phrase-to-phrase-matching.zip
# ! unzip -q /content/cpc-data.zip -d cpc_data
# ! rm /content/cpc-data.zip
# ! unzip -q /content/pppm-abstract.zip -d data
# ! rm /content/pppm-abstract.zip

# %%
# ! pip -q install sentencepiece
# ! pip -q install transformers --upgrade
# ! pip -q install tokenizers --upgrade

# %% [markdown]
# ## Import Library

# %%
#!/usr/bin/env python
# -*- coding:utf-8 -*-
# author:quincy qiang

import os
import random
import warnings
import pandas as pd

import numpy as np
import torch
from transformers import (AutoModelForMaskedLM,
                          AutoTokenizer, LineByLineTextDataset,
                          DataCollatorForLanguageModeling,
                          Trainer, TrainingArguments)

warnings.filterwarnings('ignore')


def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True


seed_torch(42)

# %% [markdown]
# ## Genegate Pretraining Corpus

# %%
df=pd.read_csv('/content/data/pppm_abstract.csv')

# %%
df=df.dropna().reset_index(drop=True)
df
# Out:
#                                                 abstract
# 0      The subject matters of the invention are: a cr...
# 1      The present invention relates to the treatment...
# 2      The invention relates to a composition compris...
# 3      The invention relates to an improved process f...
# 4      The present invention relates to a new method ...
# ...                                                  ...
# 93657  Individual measuring sensors each have a diffe...
# 93658  Vehicle (10, 100) comprising at least three dr...
# 93659  A customer loyalty programme operated by an op...
# 93660  An inflatable pipe tube fabric assembly for G-...
# 93661  A deck leverage anchor (40) for securing an ex...
#
# [93662 rows x 1 columns]

# %%
with open('corpus.txt','w',encoding='utf-8') as f:
    for ab in df['abstract']:
        f.write(ab+'\n')

# %% [markdown]
# ## Training Model

# %%
model_name = 'microsoft/deberta-v3-large'

model = AutoModelForMaskedLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.save_pretrained('/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large')

train_dataset = LineByLineTextDataset(
    tokenizer=tokenizer,
    file_path="./corpus.txt",  # mention train text file here
    block_size=256)

valid_dataset = LineByLineTextDataset(
    tokenizer=tokenizer,
    file_path="./corpus.txt",  # mention valid text file here
    block_size=256)

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15)

training_args = TrainingArguments(
    output_dir="/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain",  # select model path for checkpoint
    overwrite_output_dir=True,
    num_train_epochs=8,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=2,
    evaluation_strategy='steps',
    save_total_limit=2,
    eval_steps=7000,
    metric_for_best_model='eval_loss',
    greater_is_better=False,
    load_best_model_at_end=False,
    prediction_loss_only=True,
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset)

trainer.train()
trainer.save_model(f'/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large')
# Out:
# Some weights of the model checkpoint at microsoft/deberta-v3-large were not used when initializing DebertaV2ForMaskedLM: ['lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.weight', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'deberta.embeddings.position_embeddings.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.classifier.bias', 'mask_predictions.dense.bias', 'lm_predictions.lm_head.LayerNorm.weight']
# - This IS expected if you are initializing DebertaV2ForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2ForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DebertaV2ForMaskedLM were not initialized from the model checkpoint at microsoft/deberta-v3-large and are newly initialized: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ***** Running training *****
#   Num examples = 95237
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 2
#   Total optimization steps = 23808
#     <div>
#
#       <progress value='23808' max='23808' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23808/23808 5:13:01, Epoch 7/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>7000</td>
#       <td>1.407800</td>
#       <td>1.331807</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.218200</td>
#       <td>1.140601</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.105900</td>
#       <td>1.038180</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 95237
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 95237
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-18500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 95237
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-20500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23000
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23000/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-22500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23500
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23500/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large-pretrain/checkpoint-23000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large
# Configuration saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large/config.json
# Model weights saved in /content/drive/MyDrive/pretrained_models/microsoft/deberta-v3-large/pytorch_model.bin
